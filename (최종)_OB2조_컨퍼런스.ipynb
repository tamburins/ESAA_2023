# %% [markdown]
# <a href="https://colab.research.google.com/github/tamburins/ESAA_2023/blob/main/(%EC%B5%9C%EC%A2%85)_OB2%EC%A1%B0_%EC%BB%A8%ED%8D%BC%EB%9F%B0%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/datasets/arushchillar/disneyland-reviews
#
# Column Description:
#
# - **Review_ID**: unique id given to each review
# - **Rating**: ranging from 1 (unsatisfied) to 5 (satisfied)
# - **Year_Month**: when the reviewer visited the theme park
# - **Reviewer_Location**: country of origin of visitor
# - **Review_Text**: comments made by visitor
# - **Disneyland_Branch**: location of Disneyland Park
#
# 목차:
#
# 1. 데이터 로드
# 2. 데이터 전처리
# 3. 텍스트 데이터 처리
# 4. 텍스트 데이터 EDA
# 5. 감성 분석
# 6. 평점별 리뷰 특징 분석
# 7. 나라별 리뷰 특징 분석
# 8. 지점별 리뷰 특징 분석

# %% [markdown]
# ## **데이터 로드**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 압축 파일의 위치(구글 드라이브 - 내 드라이브 위치)
drive_path = "/content/drive/MyDrive/ESAA/OB/project/"
source_filename = drive_path + "Disneyland Reviews/archive.zip"

# 저장할 경로
extract_folder = "dataset/" # 코랩 환경에 임시 저장

# 압축 해제
import shutil
shutil.unpack_archive(source_filename, extract_folder)

# %%
import re   # regrex
import pandas as pd
import numpy as np
import datetime as dt

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from textblob import TextBlob
from collections import Counter

import warnings
warnings.filterwarnings(action = 'ignore')

# %%
data = pd.read_csv("dataset/DisneylandReviews.csv", encoding='latin-1')
data.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %%
## 임시 데이터
dat = data.copy()
dat.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %% [markdown]
# ## **데이터 전처리**

# %%
## 불필요 변수 제거
dat.drop("Review_ID", axis=1, inplace=True)

# %%
## 날짜 데이터 처리
dat["Year_Month"] = dat["Year_Month"].apply(pd.to_datetime, errors ='coerce') # 날짜 형식 지정
dat.dropna(inplace=True) # 결측치 제거

dat["year"] = dat["Year_Month"].dt.year
dat["month"] = dat["Year_Month"].dt.month

dat.drop("Year_Month", axis=1, inplace=True)

# %%
## Branch 값 단순화
dat["Branch"] = dat["Branch"].apply(lambda x : x.split("_")[1])

# %%
dat.head()
# Out:
#    Rating     Reviewer_Location  \
# 0       4             Australia
# 1       4           Philippines
# 2       4  United Arab Emirates
# 3       4             Australia
# 4       4        United Kingdom
#
#                                          Review_Text    Branch  year  month
# 0  If you've ever been to Disneyland anywhere you...  HongKong  2019      4
# 1  Its been a while since d last time we visit HK...  HongKong  2019      5
# 2  Thanks God it wasn   t too hot or too humid wh...  HongKong  2019      4
# 3  HK Disneyland is a great compact park. Unfortu...  HongKong  2019      4
# 4  the location is not in the city, took around 1...  HongKong  2019      4

# %% [markdown]
# ## **텍스트 데이터 처리**

# %%
texts = dat['Review_Text'].values

#=====
processed_texts = []

for sentence in range(0, len(texts)):
    # http: urls 제거
    processed_text = re.sub('(https?://\S+)', '', str(texts[sentence]))

    # 숫자 제거
    processed_text = re.sub(r'\d+',' ',processed_text)

    # 특수문자 제거
    processed_text = re.sub(r'\W', ' ', processed_text)

    # 단일문자 제거
    processed_text= re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_text)
    processed_text = re.sub(r'\^[a-zA-Z]\s+', ' ', processed_text)

    # 다중 공백을 단일 공백(띄어쓰기)으로 변경
    processed_text = re.sub(r'\s+', ' ', processed_text, flags=re.I)

    # 이메일 삭제
    processed_text =re.sub(r'[\w\.-]+@[\w\.-]+', '', processed_text)

    # 소문자로 변환
    processed_text = processed_text.lower()

    # 축약 표현 처리
    processed_text = re.sub(r"i'm","i am",processed_text)
    processed_text = re.sub(r"he's","he is",processed_text)
    processed_text = re.sub(r"she's","she is",processed_text)
    processed_text = re.sub(r"that's","that is",processed_text)
    processed_text = re.sub(r"what's","what is",processed_text)
    processed_text = re.sub(r"where's","where is",processed_text)
    processed_text = re.sub(r"\'ll"," will",processed_text)
    processed_text = re.sub(r"\'ve"," have",processed_text)
    processed_text = re.sub(r"youve","you have",processed_text)
    processed_text = re.sub(r"\'re"," are",processed_text)
    processed_text = re.sub(r"\'d"," would",processed_text)
    processed_text = re.sub(r"won't","will not",processed_text)
    processed_text = re.sub(r"can't","cannot",processed_text)

    processed_texts.append(processed_text)
#=====

dat['Processed_Text'] = processed_texts
dat.head()
# Out:
#    Rating     Reviewer_Location  \
# 0       4             Australia
# 1       4           Philippines
# 2       4  United Arab Emirates
# 3       4             Australia
# 4       4        United Kingdom
#
#                                          Review_Text    Branch  year  month  \
# 0  If you've ever been to Disneyland anywhere you...  HongKong  2019      4
# 1  Its been a while since d last time we visit HK...  HongKong  2019      5
# 2  Thanks God it wasn   t too hot or too humid wh...  HongKong  2019      4
# 3  HK Disneyland is a great compact park. Unfortu...  HongKong  2019      4
# 4  the location is not in the city, took around 1...  HongKong  2019      4
#
#                                       Processed_Text
# 0  if you ve ever been to disneyland anywhere you...
# 1  its been while since last time we visit hk dis...
# 2  thanks god it wasn too hot or too humid when w...
# 3  hk disneyland is great compact park unfortunat...
# 4  the location is not in the city took around ho...

# %% [markdown]
# ## **텍스트 데이터 EDA**

# %% [markdown]
# 추가적으로 성능 향상을 위한 전처리를 위해 앞서 전처리 된 리뷰 텍스트를 확인한다.

# %%
from textblob import Word
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.corpus import stopwords

# Remove StopWords
stop = stopwords.words('english')
dat['EDA_Text'] = dat['Processed_Text'].apply(lambda x : ' '.join(x for x in x.split() if x not in stop))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# 긍정적 리뷰에서 빈도 높은 단어
pos_data = dat[dat['Rating'] >= 4]
most_common = Counter(' '.join(pos_data['EDA_Text']).split()).most_common(50)
pos_df = pd.DataFrame(most_common, columns = ['Words', 'Freq'])

plt.figure(figsize = (15,7))
sns.barplot(data = pos_df, x = 'Words', y = 'Freq')
plt.title('positive - Most Common words')
plt.xticks(rotation = 60)
plt.show()

# %%
# 부정적 리뷰에서 빈도 높은 단어
neg_data = dat[dat['Rating'] <= 3]
most_common = Counter(' '.join(neg_data['EDA_Text']).split()).most_common(50)
neg_df = pd.DataFrame(most_common, columns = ['Words', 'Freq'])

plt.figure(figsize = (15,7))
sns.barplot(data = neg_df, x = 'Words', y = 'Freq')
plt.title('negative - Most Common words')
plt.xticks(rotation = 60)
plt.show()

# %%
# 두 그룹에 동시에 존재하는 단어를 확인
common_words = set(neg_df['Words']).intersection(set(pos_df['Words']))
common_words
# Out:
# {'also',
#  'around',
#  'back',
#  'day',
#  'disney',
#  'disneyland',
#  'even',
#  'experience',
#  'fast',
#  'first',
#  'food',
#  'get',
#  'go',
#  'good',
#  'great',
#  'kids',
#  'like',
#  'long',
#  'many',
#  'much',
#  'one',
#  'park',
#  'parks',
#  'pass',
#  'people',
#  'place',
#  'really',
#  'ride',
#  'rides',
#  'see',
#  'time',
#  'times',
#  'us',
#  'visit',
#  'wait',
#  'went',
#  'would'}

# %%
# 두 그룹에 동시에 존재하지 않는 단어 추출
neg_words = set(neg_df['Words'])
pos_words = set(pos_df['Words'])

exclusive_to_neg = neg_words.difference(pos_words)
exclusive_to_pos = pos_words.difference(neg_words)

print('neg에만 높은 빈도로 존재하는 단어들 : ',exclusive_to_neg)
print('pos에만 높은 빈도로 존재하는 단어들 : ',exclusive_to_pos)
# Out:
# neg에만 높은 빈도로 존재하는 단어들 :  {'hour', 'minutes', 'closed', 'money', 'staff', 'line', 'queue', 'queues', 'hours', 'paris', 'children', 'got', 'could'}
# pos에만 높은 빈도로 존재하는 단어들 :  {'world', 'show', 'parade', 'fireworks', 'well', 'mountain', 'days', 'loved', 'fun', 'still', 'year', 'characters', 'take'}

# %% [markdown]
# 동시에 존재하는 단어가 많이 존재하지만, 리뷰 텍스트로 분류 모델을 개발할 때는 정보 손실의 문제가 있어 동시 존재 단어 제거에 주의해야한다.
#
# 문맥 고려에 중요한 역할을 하는 단어들일 수도 있기 때문에 이를 바로 제거하는 것은 옳지 않다.

# %%
# 3점 데이터 경향성 확인
data_3 = dat[dat['Rating'] == 3]
most_common = Counter(' '.join(data_3['EDA_Text']).split()).most_common(50)
df_3 = pd.DataFrame(most_common, columns = ['Words', 'Freq'])

plt.figure(figsize = (15,7))
sns.barplot(data = df_3, x = 'Words', y = 'Freq')
plt.title('3 data - Most Common words')
plt.xticks(rotation = 60)
plt.show()

# %%
words_3 = set(df_3['Words'])

unexclusive_to_neg = words_3.difference(neg_words)
unexclusive_to_pos = words_3.difference(pos_words)

print('부정적에는 없고, 3점에만 있는 단어들 : ',unexclusive_to_neg)
print('긍정적에는 없고, 3점에만 있는 단어들 : ',unexclusive_to_pos)
# Out:
# 부정적에는 없고, 3점에만 있는 단어들 :  {'world', 'expensive', 'lines', 'small', 'attractions'}
# 긍정적에는 없고, 3점에만 있는 단어들 :  {'expensive', 'children', 'closed', 'lines', 'staff', 'line', 'queue', 'queues', 'could', 'paris', 'small', 'attractions'}

# %% [markdown]
# ## **감성 분석**

# %%
# 극성 점수
def getPolarity(text):
   return  TextBlob(text).sentiment.polarity

dat['Polarity'] = dat['Processed_Text'].apply(getPolarity)

# %%
## 정답 레이블
# Rating 3 이하 → Negative로 분류
dat['Sentiment'] = dat['Rating'].apply(lambda x: 'Negative' if x <= 3 else 'Positive')
dat['Sentiment'].value_counts()
# Out:
# Positive    31994
# Negative     8049
# Name: Sentiment, dtype: int64

# %% [markdown]
# **분석**

# %%
## 예측 레이블
# 극성 점수 < 0 → Negative로 분류
def getAnalysis(score):
 if score < 0:
  return 'Negative'
 else:
  return 'Positive'

dat['Analysis'] = dat['Polarity'].apply(getAnalysis)

# %% [markdown]
# **결과 비교**

# %%
dat['Result'] = dat.apply(lambda row: 'Correct' if row['Analysis'] == row['Sentiment'] else 'Incorrect', axis = 1)
dat['Result'].value_counts()
# Out:
# Correct      32897
# Incorrect     7146
# Name: Result, dtype: int64

# %%
# 맞춘 비율
len(dat[dat['Result']=='Correct'])/len(dat)
# Out:
# 0.8215418425192917

# %%
# Negative를 Negative로 잘 분류한 비율
dat_Neg = dat[dat['Sentiment']=='Negative']
len(dat_Neg[dat_Neg['Analysis']=='Negative'])/len(dat_Neg)
# Out:
# 0.27431979127841966

# %%
# Positve를 Positive로 잘 분류한 비율
dat_Pos = dat[dat['Sentiment']=='Positive']
len(dat_Pos[dat_Pos['Analysis']=='Positive'])/len(dat_Pos)
# Out:
# 0.9592111020816403

# %%
# 실제론 Negative인데 Positive로 잘못 분류한 비율
dat_Neg = dat[dat['Sentiment']=='Negative']
len(dat_Neg[dat_Neg['Analysis']=='Positive'])/len(dat_Neg)
# Out:
# 0.7256802087215803

# %%
# 실제론 Positive인데 Negative로 잘못 분류한 비율
dat_Pos = dat[dat['Sentiment']=='Positive']
len(dat_Pos[dat_Pos['Analysis']=='Negative'])/len(dat_Pos)
# Out:
# 0.04078889791835969

# %%
# Incorrect
incorrect_index = dat.loc[dat['Result'] == 'Incorrect'].index
incorrect_data = dat.loc[incorrect_index]
incorrect_data[['Rating','Review_Text','Polarity','Sentiment','Analysis','Result']]
# Out:
#        Rating                                        Review_Text  Polarity  \
# 7           3  Think of it as an intro to Disney magic for th...  0.054722
# 21          3  First off I'm not a really big Disneyland fan....  0.201256
# 22          3  Mickey and the Wounderous book was great and t...  0.306687
# 23          3  I   ve been to Hong Kong Disneyland twice and ...  0.102803
# 25          3  Disneylands the world over are generic apart f...  0.060000
# ...       ...                                                ...       ...
# 42098       1     250 total for tickets, parking and food for...  0.053563
# 42104       1  I was thrilled to check out a Disney park outs...  0.087500
# 42108       3  I just wanted to post a word of warning about ...  0.137500
# 42115       1  We spent the 20 Dec 2010 in the Disney park an...  0.020628
# 42116       2  Well I was really looking forward to this trip...  0.125890
#
#       Sentiment  Analysis     Result
# 7      Negative  Positive  Incorrect
# 21     Negative  Positive  Incorrect
# 22     Negative  Positive  Incorrect
# 23     Negative  Positive  Incorrect
# 25     Negative  Positive  Incorrect
# ...         ...       ...        ...
# 42098  Negative  Positive  Incorrect
# 42104  Negative  Positive  Incorrect
# 42108  Negative  Positive  Incorrect
# 42115  Negative  Positive  Incorrect
# 42116  Negative  Positive  Incorrect
#
# [7146 rows x 6 columns]

# %% [markdown]
# ## **평점별 리뷰 특징 분석**

# %%
df_Pos = dat[(dat['Rating']==4) | (dat['Rating']==5)]
df_Neg = dat[(dat['Rating']==1) | (dat['Rating']==2)]

# %%
text_Pos = " ".join(i for i in df_Pos.Processed_Text)

# %%
wordcloud_Pos = WordCloud(
    colormap="summer", background_color = 'white',
    collocations=False).generate(text_Pos)

plt.figure(figsize=[11,11])
plt.imshow(wordcloud_Pos, interpolation="bilinear")
plt.axis("off")
plt.title("Positive Review")
plt.show()

# %%
text_Neg = " ".join(i for i in df_Neg.Processed_Text)

# %%
wordcloud_Neg = WordCloud(
    colormap="spring", background_color = 'white',
    collocations=False).generate(text_Neg)

plt.figure(figsize=[11,11])
plt.imshow(wordcloud_Neg, interpolation="bilinear")
plt.axis("off")
plt.title("Negative Review")
plt.show()

# %%
df_rate1 = dat[dat['Rating']==1]
df_rate2 = dat[dat['Rating']==2]
df_rate3 = dat[dat['Rating']==3]
df_rate4 = dat[dat['Rating']==4]
df_rate5 = dat[dat['Rating']==5]

# %%
stop3 = ['disney','park','time','ride','day','days','disneyland','parks','rides','get','go','one','went']

# %%
df_rate1['Processed_Text'] = df_rate1['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop3)))
most_common = Counter(' '.join(df_rate1['Processed_Text']).split()).most_common(10)
mco_df1 = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df1, x = 'Words', y = 'Freq')
plt.title('review of rating 1')
plt.xticks(rotation = 60)
plt.show()

# %%
df_rate2['Processed_Text'] = df_rate2['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop3)))
most_common = Counter(' '.join(df_rate2['Processed_Text']).split()).most_common(10)
mco_df2 = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df2, x = 'Words', y = 'Freq')
plt.title('review of rating 2')
plt.xticks(rotation = 60)
plt.show()

# %%
df_rate3['Processed_Text'] = df_rate3['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop3)))
most_common = Counter(' '.join(df_rate3['Processed_Text']).split()).most_common(10)
mco_df3 = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df3, x = 'Words', y = 'Freq')
plt.title('review of rating 3')
plt.xticks(rotation = 60)
plt.show()

# %%
df_rate4['Processed_Text'] = df_rate4['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop3)))
most_common = Counter(' '.join(df_rate4['Processed_Text']).split()).most_common(10)
mco_df4 = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df4, x = 'Words', y = 'Freq')
plt.title('review of rating 4')
plt.xticks(rotation = 60)
plt.show()

# %%
df_rate5['Processed_Text'] = df_rate5['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop3)))
most_common = Counter(' '.join(df_rate5['Processed_Text']).split()).most_common(10)
mco_df5 = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df5, x = 'Words', y = 'Freq')
plt.title('review of rating 5')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# - 1~2점대 리뷰
#   + people
#   + long
#   + wait
#   + closed
#   + staff
#
# - 3점대 리뷰
#   + food, long, people
#   + really, kids, good, like
#
# - 4~5점대 리뷰
#   + great
#   + kids
#   + fun
#   + good
#   + really
#
# > - 전반적으로 부정적인 리뷰는 긴 대기시간, 어트랙션 미운영, 스태프나 음식에 대한 불만에 대한 내용이 많고 긍정적인 리뷰는 아이나 즐거운 경험에 대한 내용이 많아 보인다
# - 특히 3점대는 긍정/부정 리뷰에서 자주 등장하는 단어가 적절히 섞여있는 것으로 보아 개인의 성향에 따라 긍정적일수도, 부정적일수도 있다. 긍정+부정의 리뷰인 경우가 종종 보인다. (긍정적인 리뷰+아쉬운점 / 부정적인 리뷰+좋았던점)

# %%
stop4 = ['disney','park','time','ride','day','days','disneyland','parks','rides','get','go','one','went','place','would','visit','people']

# %%
df_Pos['Processed_Text'] = df_Pos['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop4)))
most_common = Counter(' '.join(df_Pos['Processed_Text']).split()).most_common(10)
mco_df_Pos = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df_Pos, x = 'Words', y = 'Freq')
plt.title('Positive Reviews')
plt.xticks(rotation = 60)
plt.show()

# %%
df_Neg['Processed_Text'] = df_Neg['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop4)))
most_common = Counter(' '.join(df_Neg['Processed_Text']).split()).most_common(10)
mco_df_Neg = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df_Neg, x = 'Words', y = 'Freq')
plt.title('Negative Reviews')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# ## **나라별 리뷰 특징 분석**

# %%
dat['Reviewer_Location'].value_counts()
# Out:
# United States               13522
# United Kingdom               9115
# Australia                    4412
# Canada                       2116
# India                        1470
#                             ...
# Turks and Caicos Islands        1
# Timor-Leste                     1
# South Sudan                     1
# Curaçao                         1
# Andorra                         1
# Name: Reviewer_Location, Length: 162, dtype: int64

# %%
# 리뷰수 적은 국가 제외 (평균 기준)
Locat = pd.DataFrame(dat['Reviewer_Location'].value_counts() > dat['Reviewer_Location'].value_counts().mean())
Locat = Locat[Locat['Reviewer_Location']==True].index

df1 = dat[dat['Reviewer_Location'].apply(lambda x: x in Locat)]
df1.head()
# Out:
#    Rating     Reviewer_Location  \
# 0       4             Australia
# 1       4           Philippines
# 2       4  United Arab Emirates
# 3       4             Australia
# 4       4        United Kingdom
#
#                                          Review_Text    Branch  year  month  \
# 0  If you've ever been to Disneyland anywhere you...  HongKong  2019      4
# 1  Its been a while since d last time we visit HK...  HongKong  2019      5
# 2  Thanks God it wasn   t too hot or too humid wh...  HongKong  2019      4
# 3  HK Disneyland is a great compact park. Unfortu...  HongKong  2019      4
# 4  the location is not in the city, took around 1...  HongKong  2019      4
#
#                                       Processed_Text  \
# 0  if you ve ever been to disneyland anywhere you...
# 1  its been while since last time we visit hk dis...
# 2  thanks god it wasn too hot or too humid when w...
# 3  hk disneyland is great compact park unfortunat...
# 4  the location is not in the city took around ho...
#
#                                             EDA_Text  Polarity Sentiment  \
# 0  ever disneyland anywhere find disneyland hong ...  0.239352  Positive
# 1  since last time visit hk disneyland yet time s...  0.205797  Positive
# 2  thanks god hot humid visiting park otherwise w...  0.119238  Positive
# 3  hk disneyland great compact park unfortunately...  0.189286  Positive
# 4  location city took around hour kowlon kids lik...  0.266667  Positive
#
#    Analysis   Result
# 0  Positive  Correct
# 1  Positive  Correct
# 2  Positive  Correct
# 3  Positive  Correct
# 4  Positive  Correct

# %%
df1 = df1.groupby(['Reviewer_Location'],as_index=False).agg({'Rating':'mean'}).sort_values(by='Rating', ascending=True)
df1.style.background_gradient(cmap="autumn", subset=['Rating'])
# Out:
# <style type="text/css">
# #T_d7266_row0_col1 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_d7266_row1_col1 {
#   background-color: #ff4f00;
#   color: #f1f1f1;
# }
# #T_d7266_row2_col1 {
#   background-color: #ff6200;
#   color: #f1f1f1;
# }
# #T_d7266_row3_col1 {
#   background-color: #ff9e00;
#   color: #000000;
# }
# #T_d7266_row4_col1 {
#   background-color: #ffa900;
#   color: #000000;
# }
# #T_d7266_row5_col1 {
#   background-color: #ffab00;
#   color: #000000;
# }
# #T_d7266_row6_col1 {
#   background-color: #ffc100;
#   color: #000000;
# }
# #T_d7266_row7_col1 {
#   background-color: #ffc900;
#   color: #000000;
# }
# #T_d7266_row8_col1 {
#   background-color: #ffcb00;
#   color: #000000;
# }
# #T_d7266_row9_col1 {
#   background-color: #ffcf00;
#   color: #000000;
# }
# #T_d7266_row10_col1, #T_d7266_row11_col1 {
#   background-color: #ffee00;
#   color: #000000;
# }
# #T_d7266_row12_col1 {
#   background-color: #ffff00;
#   color: #000000;
# }
# </style>
# <table id="T_d7266" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7266_level0_col0" class="col_heading level0 col0" >Reviewer_Location</th>
#       <th id="T_d7266_level0_col1" class="col_heading level0 col1" >Rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7266_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_d7266_row0_col0" class="data row0 col0" >Hong Kong</td>
#       <td id="T_d7266_row0_col1" class="data row0 col1" >3.834951</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row1" class="row_heading level0 row1" >9</th>
#       <td id="T_d7266_row1_col0" class="data row1 col0" >Singapore</td>
#       <td id="T_d7266_row1_col1" class="data row1 col1" >4.024717</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_d7266_row2_col0" class="data row2 col0" >United Kingdom</td>
#       <td id="T_d7266_row2_col1" class="data row2 col1" >4.069885</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row3" class="row_heading level0 row3" >10</th>
#       <td id="T_d7266_row3_col0" class="data row3 col0" >United Arab Emirates</td>
#       <td id="T_d7266_row3_col1" class="data row3 col1" >4.215339</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row4" class="row_heading level0 row4" >6</th>
#       <td id="T_d7266_row4_col0" class="data row4 col0" >Malaysia</td>
#       <td id="T_d7266_row4_col1" class="data row4 col1" >4.241993</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7266_row5_col0" class="data row5 col0" >Ireland</td>
#       <td id="T_d7266_row5_col1" class="data row5 col1" >4.245614</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row6" class="row_heading level0 row6" >1</th>
#       <td id="T_d7266_row6_col0" class="data row6 col0" >Canada</td>
#       <td id="T_d7266_row6_col1" class="data row6 col1" >4.298677</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row7" class="row_heading level0 row7" >0</th>
#       <td id="T_d7266_row7_col0" class="data row7 col0" >Australia</td>
#       <td id="T_d7266_row7_col1" class="data row7 col1" >4.317543</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row8" class="row_heading level0 row8" >4</th>
#       <td id="T_d7266_row8_col0" class="data row8 col0" >Indonesia</td>
#       <td id="T_d7266_row8_col1" class="data row8 col1" >4.322896</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row9" class="row_heading level0 row9" >12</th>
#       <td id="T_d7266_row9_col0" class="data row9 col0" >United States</td>
#       <td id="T_d7266_row9_col1" class="data row9 col1" >4.331756</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row10" class="row_heading level0 row10" >8</th>
#       <td id="T_d7266_row10_col0" class="data row10 col0" >Philippines</td>
#       <td id="T_d7266_row10_col1" class="data row10 col1" >4.405273</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row11" class="row_heading level0 row11" >7</th>
#       <td id="T_d7266_row11_col0" class="data row11 col0" >New Zealand</td>
#       <td id="T_d7266_row11_col1" class="data row11 col1" >4.406162</td>
#     </tr>
#     <tr>
#       <th id="T_d7266_level0_row12" class="row_heading level0 row12" >3</th>
#       <td id="T_d7266_row12_col0" class="data row12 col0" >India</td>
#       <td id="T_d7266_row12_col1" class="data row12 col1" >4.448299</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - Hong Kong: 상대적으로 점수 낮게 주는 경향을 보인다.
# - India: 상대적으로 점수 높게 주는 경향을 보인다.

# %%
# India (상대적으로 점수 높게 주는 국가)
Rat_India = dat[dat['Reviewer_Location']=='India'].Rating.value_counts()
Rat_India.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='Rating'>

# %%
# HongKong (상대적으로 점수 낮게 주는 국가)
Rat_HongKong = dat[dat['Reviewer_Location']=='Hong Kong'].Rating.value_counts()
Rat_HongKong.plot.pie(autopct='%.2f%%')
# Out:
# <Axes: ylabel='Rating'>

# %% [markdown]
# ## **지점별 리뷰 특징 분석**

# %%
df_Cal = dat.loc[dat['Branch']=='California']
df_Par = dat.loc[dat['Branch']=='Paris']
df_Hong = dat.loc[dat['Branch']=='HongKong']

# %%
stop2 = ['park','parks','disney','disneyland','paris','california','hongkong','would','go','get','like','one','good','us','day']

# %%
df_Cal['Processed_Text'] = df_Cal['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop2)))
df_Par['Processed_Text'] = df_Par['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop2)))
df_Hong['Processed_Text'] = df_Hong['Processed_Text'].apply(lambda x : " ".join(x for x in x.split() if x not in (stop + stop2)))

# %%
# !pip install wordcloud

from wordcloud import WordCloud
from wordcloud import STOPWORDS
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# wordcloud of California
text_Cal = " ".join(i for i in df_Cal.Processed_Text)

wordcloud_Cal = WordCloud(
    colormap="seismic", background_color = 'white',
    collocations=False).generate(text_Cal)

plt.figure(figsize=[11,11])
plt.imshow(wordcloud_Cal, interpolation="bilinear")
plt.axis("off")
plt.title("Review of California")
plt.show()

# %%
# wordcloud of Paris

text_Par = " ".join(i for i in df_Par.Processed_Text)

wordcloud_Par = WordCloud(
    colormap="seismic", background_color = 'white',
    collocations=False).generate(text_Par)

plt.figure(figsize=[11,11])
plt.imshow(wordcloud_Par, interpolation="bilinear")
plt.axis("off")
plt.title("Review of Paris")
plt.show()

# %%
# wordcloud of Hongkong

text_Hong = " ".join(i for i in df_Hong.Processed_Text)

wordcloud_Hong = WordCloud(
    colormap="seismic", background_color = 'white',
    collocations=False).generate(text_Hong)

plt.figure(figsize=[11,11])
plt.imshow(wordcloud_Hong, interpolation="bilinear")
plt.axis("off")
plt.title("Review of Hongkong")
plt.show()

# %%
# 지점별 긍정/부정 빈도 수 비교
plt.figure(figsize=(10,6))
sns.countplot(data=dat,x='Branch',hue='Sentiment',palette='inferno')
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
# 지점별 긍정/부정 비율 비교
label_Cal = df_Cal['Sentiment'].value_counts(sort = True).index
size_Cal = df_Cal['Sentiment'].value_counts(sort = True)

label_Par =df_Par['Sentiment'].value_counts(sort = True).index
size_Par = df_Par['Sentiment'].value_counts(sort = True)

label_Hong = df_Hong['Sentiment'].value_counts(sort = True).index
size_Hong = df_Hong['Sentiment'].value_counts(sort = True)


fig, axes = plt.subplots(1, 3, figsize=(20, 7), sharey=False)
fig.suptitle('Branches')
axes[0].pie(size_Hong,labels=label_Cal,startangle=90,shadow=1,autopct='%1.2f%%',colors=['#1e7dd6','#CC0000'])
axes[0].set_title('HongKong')
axes[1].pie(size_Cal,labels=label_Par,startangle=90,shadow=1,autopct='%1.2f%%',colors=['#1e7dd6','#CC0000'])
axes[1].set_title('California')
axes[2].pie(size_Par,labels=label_Hong,startangle=90,shadow=1,autopct='%1.2f%%',colors=['#1e7dd6','#CC0000'])
axes[2].set_title('Paris')
# Out:
# Text(0.5, 1.0, 'Paris')

# %% [markdown]
# - Paris 지점의 Negative 비율이 다른 지점에 비해 상대적으로 높다.

# %% [markdown]
# **왜 Paris 지점의 부정 리뷰 비율이 높을까?**

# %%
df_Par_Neg = df_Par[df_Par['Sentiment']=='Negative']
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
df_Par_Neg['Processed_Text'] = df_Par_Neg['Processed_Text'].apply(lambda x : " ".join(lemmatizer.lemmatize(word) for word in x.split()))
most_common = Counter(' '.join(df_Par_Neg['Processed_Text']).split()).most_common(10)
mco_df = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df, x = 'Words', y = 'Freq')
plt.title('Paris')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# **Paris**
# - food: 음식이 비싸다. 퀄리티가 낮다.
# - staff: 스태프 수 부족, 태도 지적 (교육 부족, 불친절)
# - closed: 운영 중단된 놀이기구

# %%
df_Cal_Neg = df_Cal[df_Cal['Sentiment']=='Negative']
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
df_Cal_Neg['Processed_Text'] = df_Cal_Neg['Processed_Text'].apply(lambda x : " ".join(lemmatizer.lemmatize(word) for word in x.split()))
most_common = Counter(' '.join(df_Cal_Neg['Processed_Text']).split()).most_common(10)
mco_df = pd.DataFrame(most_common, columns = ['Words', 'Freq'])
plt.figure(figsize = (15,7))
sns.barplot(data = mco_df, x = 'Words', y = 'Freq')
plt.title('California')
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# **California**
# - 줄이 길고 사람이 많다. → 어느 놀이공원에서나 보이는 기본적인 문제점들만 보유

# %%
# 파리 지점 부정 리뷰 살펴보기
pd.DataFrame(df_Par_Neg[['Review_Text', 'Rating']]).head()
# Out:
#                                              Review_Text  Rating
# 29034  We booked tickets on line for Disneyland, this...       2
# 29042  After multiple visits to the original Disneyla...       3
# 29043  Why they selling fastpass tickets without have...       1
# 29047  We went to Disneyland Paris during the Easter ...       2
# 29053  Its a shame this park carry the name Disney......       1

# %% [markdown]
# **파리 디즈니랜드**
#
# 1. 지리적 입지 문제
# 프랑스 파리 근교의 날씨는 놀이 공원에 적합하지 않다.
# 여름에는 건조하고 겨울에는 비가 많이 내려 습하기 때문이다.
#
# 2. 음식 문제
# 디즈니사는 놀이공원에서 사람들이 점심을 간단하게 샌드위치나 핫도그 등으로 해결할 것으로 생각했다.
# 그러나 프랑스인들은 간단한 것으로 점심을 떼우기보다는 좀더 포멀한 식당을 찾았다.
# 이로 인해 식당은 턱없이 부족했고, 이 때문에 기다리는 시간도 오래 걸려 많은 사람들이 불편을 겪게 되었다.
